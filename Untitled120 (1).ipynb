# %%
# !pip install hqq==0.1.8
# Out:
# Collecting hqq==0.1.8
#   Downloading hqq-0.1.8.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (1.26.4)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (4.67.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (0.8.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (1.3.0)
# Requirement already satisfied: transformers>=4.36.1 in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (4.48.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (0.28.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from hqq==0.1.8) (2.5.0)
# Collecting bitblas (from hqq==0.1.8)
#   Downloading bitblas-0.1.0.post1-py3-none-manylinux1_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (3.17.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.1->hqq==0.1.8) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->hqq==0.1.8) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->hqq==0.1.8) (4.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate->hqq==0.1.8) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate->hqq==0.1.8) (2.5.1+cu124)
# Requirement already satisfied: Cython in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (3.0.12)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (25.1.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (1.17.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (3.1.1)
# Collecting cpplint (from bitblas->hqq==0.1.8)
#   Downloading cpplint-2.0.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (4.4.2)
# Requirement already satisfied: docutils in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (0.21.2)
# Collecting dtlib (from bitblas->hqq==0.1.8)
#   Downloading dtlib-0.0.0.dev2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (0.4.1)
# Requirement already satisfied: pytest>=6.2.4 in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (8.3.5)
# Collecting pytest-xdist>=2.2.1 (from bitblas->hqq==0.1.8)
#   Downloading pytest_xdist-3.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (1.13.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (0.9.0)
# Collecting thefuzz (from bitblas->hqq==0.1.8)
#   Downloading thefuzz-0.22.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tornado in /usr/local/lib/python3.11/dist-packages (from bitblas->hqq==0.1.8) (6.4.2)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest>=6.2.4->bitblas->hqq==0.1.8) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest>=6.2.4->bitblas->hqq==0.1.8) (1.5.0)
# Collecting execnet>=2.1 (from pytest-xdist>=2.2.1->bitblas->hqq==0.1.8)
#   Downloading execnet-2.1.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hqq==0.1.8) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hqq==0.1.8) (3.1.5)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hqq==0.1.8) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hqq==0.1.8) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->accelerate->hqq==0.1.8)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hqq==0.1.8) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate->hqq==0.1.8) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate->hqq==0.1.8) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi->bitblas->hqq==0.1.8) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.1->hqq==0.1.8) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.1->hqq==0.1.8) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.1->hqq==0.1.8) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.1->hqq==0.1.8) (2025.1.31)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from thefuzz->bitblas->hqq==0.1.8)
#   Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate->hqq==0.1.8) (3.0.2)
# Downloading bitblas-0.1.0.post1-py3-none-manylinux1_x86_64.whl (81.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 MB 13.7 MB/s eta 0:00:00
# Downloading pytest_xdist-3.6.1-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.5 MB/s eta 0:00:00
# Downloading cpplint-2.0.0-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 8.1 MB/s eta 0:00:00
# Downloading dtlib-0.0.0.dev2-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 5.5 MB/s eta 0:00:00
# Downloading thefuzz-0.22.1-py3-none-any.whl (8.2 kB)
# Downloading execnet-2.1.1-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 4.1 MB/s eta 0:00:00
# Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 100.2 MB/s eta 0:00:00
# Building wheels for collected packages: hqq
#   Building wheel for hqq (setup.py) ... done
#   Created wheel for hqq: filename=hqq-0.1.8-py3-none-any.whl size=61842 sha256=fafc3ac5beb6163da7916506f41f9e433aa8957da33a5f9e790c6a12dabe3286
#   Stored in directory: /root/.cache/pip/wheels/48/c9/d7/e9a4d0e9ff9ec96c2b629713b55e0221fee3f1ca41071b0a5e
# Successfully built hqq
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Installing collected packages: cpplint, rapidfuzz, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, execnet, dtlib, thefuzz, pytest-xdist, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitblas, hqq
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitblas-0.1.0.post1 cpplint-2.0.0 dtlib-0.0.0.dev2 execnet-2.1.1 hqq-0.1.8 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytest-xdist-3.6.1 rapidfuzz-3.12.2 thefuzz-0.22.1

# %%
# !pip install transformers==4.46.0
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting transformers==4.46.0
#   Downloading transformers-4.46.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (0.5.3)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.46.0)
#   Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.0) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.0) (2025.1.31)
# WARNING: The candidate selected for download or install is a yanked version: 'transformers' candidate (version 4.46.0 at https://files.pythonhosted.org/packages/db/88/1ef8a624a33d7fe460a686b9e0194a7916320fc0d67d4e38e570beeac039/transformers-4.46.0-py3-none-any.whl (from https://pypi.org/simple/transformers/) (requires-python:>=3.8.0))
# Reason for being yanked: This version unfortunately does not work with 3.8 but we did not drop the support yet
# Downloading transformers-4.46.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 106.9 MB/s eta 0:00:00
# Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 91.6 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
#     Uninstalling tokenizers-0.21.0:
#       Successfully uninstalled tokenizers-0.21.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.3
#     Uninstalling transformers-4.48.3:
#       Successfully uninstalled transformers-4.48.3
# Successfully installed tokenizers-0.20.3 transformers-4.46.0

# %%
# !pip uninstall torch torchaudio torchvision -y
# Out:
# Found existing installation: torch 2.5.1+cu124
# Uninstalling torch-2.5.1+cu124:
#   Successfully uninstalled torch-2.5.1+cu124
# Found existing installation: torchaudio 2.5.1+cu124
# Uninstalling torchaudio-2.5.1+cu124:
#   Successfully uninstalled torchaudio-2.5.1+cu124
# Found existing installation: torchvision 0.20.1+cu124
# Uninstalling torchvision-0.20.1+cu124:
#   Successfully uninstalled torchvision-0.20.1+cu124

# %%
# !wget https://download.pytorch.org/whl/cu124/torch-2.4.0%2Bcu124-cp311-cp311-linux_x86_64.whl#sha256=81397ff1c84a3f2c666d2627144ecac268665325726267e092a80113385ad3e8
# Out:
# --2025-03-08 22:34:01--  https://download.pytorch.org/whl/cu124/torch-2.4.0%2Bcu124-cp311-cp311-linux_x86_64.whl
# Resolving download.pytorch.org (download.pytorch.org)... 3.165.102.36, 3.165.102.62, 3.165.102.113, ...
# Connecting to download.pytorch.org (download.pytorch.org)|3.165.102.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 797323942 (760M) [binary/octet-stream]
# Saving to: ‘torch-2.4.0+cu124-cp311-cp311-linux_x86_64.whl’
#
# torch-2.4.0+cu124-c 100%[===================>] 760.39M   149MB/s    in 4.7s
#
# 2025-03-08 22:34:06 (162 MB/s) - ‘torch-2.4.0+cu124-cp311-cp311-linux_x86_64.whl’ saved [797323942/797323942]

# %%
# !pip install torch-2.4.0+cu124-cp311-cp311-linux_x86_64.whl
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/hqq_aten-0.0.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Processing ./torch-2.4.0+cu124-cp311-cp311-linux_x86_64.whl
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0+cu124) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0+cu124) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0+cu124) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0+cu124) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0+cu124) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0+cu124) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.99 (from torch==2.4.0+cu124)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.99 (from torch==2.4.0+cu124)
#   Downloading nvidia_cuda_runtime_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.99 (from torch==2.4.0+cu124)
#   Downloading nvidia_cuda_cupti_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0+cu124) (9.1.0.70)
# Collecting nvidia-cublas-cu12==12.4.2.65 (from torch==2.4.0+cu124)
#   Downloading nvidia_cublas_cu12-12.4.2.65-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.0.44 (from torch==2.4.0+cu124)
#   Downloading nvidia_cufft_cu12-11.2.0.44-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.119 (from torch==2.4.0+cu124)
#   Downloading nvidia_curand_cu12-10.3.5.119-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.0.99 (from torch==2.4.0+cu124)
#   Downloading nvidia_cusolver_cu12-11.6.0.99-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.0.142 (from torch==2.4.0+cu124)
#   Downloading nvidia_cusparse_cu12-12.3.0.142-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.4.0+cu124)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.99 (from torch==2.4.0+cu124)
#   Downloading nvidia_nvtx_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.99 (from torch==2.4.0+cu124)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.0.0 (from torch==2.4.0+cu124)
#   Downloading triton-3.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.4.0+cu124) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.4.0+cu124) (1.3.0)
# Downloading nvidia_cublas_cu12-12.4.2.65-py3-none-manylinux2014_x86_64.whl (363.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.0/363.0 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 98.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (24.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 84.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.4/883.4 kB 62.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.0.44-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.119-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.0.99-py3-none-manylinux2014_x86_64.whl (128.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 MB 8.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.0.142-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.8 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.6 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.4 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 6.7 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.4.127
#     Uninstalling nvidia-nvjitlink-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.5.147
#     Uninstalling nvidia-curand-cu12-10.3.5.147:
#       Successfully uninstalled nvidia-curand-cu12-10.3.5.147
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.1.3
#     Uninstalling nvidia-cufft-cu12-11.2.1.3:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.1.3
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.4.127
#     Uninstalling nvidia-cuda-runtime-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.127
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.4.127
#     Uninstalling nvidia-cuda-cupti-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.4.127
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.4.5.8
#     Uninstalling nvidia-cublas-cu12-12.4.5.8:
#       Successfully uninstalled nvidia-cublas-cu12-12.4.5.8
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.3.1.170
#     Uninstalling nvidia-cusparse-cu12-12.3.1.170:
#       Successfully uninstalled nvidia-cusparse-cu12-12.3.1.170
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.1.9
#     Uninstalling nvidia-cusolver-cu12-11.6.1.9:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.1.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# timm 1.0.15 requires torchvision, which is not installed.
# fastai 2.7.18 requires torchvision>=0.11, which is not installed.
# Successfully installed nvidia-cublas-cu12-12.4.2.65 nvidia-cuda-cupti-cu12-12.4.99 nvidia-cuda-nvrtc-cu12-12.4.99 nvidia-cuda-runtime-cu12-12.4.99 nvidia-cufft-cu12-11.2.0.44 nvidia-curand-cu12-10.3.5.119 nvidia-cusolver-cu12-11.6.0.99 nvidia-cusparse-cu12-12.3.0.142 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.4.99 torch-2.4.0+cu124 triton-3.0.0

# %%
model_id = 'mobiuslabsgmbh/Llama-2-70b-hf-2bit_g16_s128-HQQ'
import torch
import transformers
# !export PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True
from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)
model     = HQQModelForCausalLM.from_quantized(model_id, compute_dtype=torch.float16, device="auto")
# Out:
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py:237: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
# Failed to load the weights
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py in from_quantized(cls, save_dir_or_hub, compute_dtype, device, cache_dir, adapter, **kwargs)
#     463         try:
# --> 464             weights = cls.load_weights(save_dir)
#     465         except Exception:
#
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py in load_weights(cls, save_dir, map_location)
#     236     def load_weights(cls, save_dir: str, map_location=None):
# --> 237         return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
#     238
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1096                         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1097                 return _load(
#    1098                     opened_zipfile,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1524     torch._utils._thread_local_state.map_location = map_location
# -> 1525     result = unpickler.load()
#    1526     del torch._utils._thread_local_state.map_location
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in persistent_load(saved_id)
#    1491             nbytes = numel * torch._utils._element_size(dtype)
# -> 1492             typed_storage = load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#    1493
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load_tensor(dtype, numel, key, location)
#    1465         typed_storage = torch.storage.TypedStorage(
# -> 1466             wrap_storage=restore_location(storage, location),
#    1467             dtype=dtype,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in default_restore_location(storage, location)
#     413     for _, _, fn in _package_registry:
# --> 414         result = fn(storage, location)
#     415         if result is not None:
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _deserialize(backend_name, obj, location)
#     391         device = _validate_device(location, backend_name)
# --> 392         return obj.to(device=device)
#     393
#
# /usr/local/lib/python3.11/dist-packages/torch/storage.py in to(self, device, non_blocking)
#     186     def to(self, *, device: torch.device, non_blocking: bool = False) -> T:  # type: ignore[type-var, misc] # noqa: E704
# --> 187         return _to(self, device, non_blocking)
#     188
#
# /usr/local/lib/python3.11/dist-packages/torch/_utils.py in _to(self, device, non_blocking)
#      88             ), f"sparse storage is not supported for {device.type.upper()} tensors"
# ---> 89             untyped_storage = torch.UntypedStorage(self.size(), device=device)
#      90             untyped_storage.copy_(self, non_blocking)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 16.12 MiB is free. Process 121954 has 14.72 GiB memory in use. Of the allocated memory 14.62 GiB is allocated by PyTorch, and 1.30 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-ade60d4803e4> in <cell line: 0>()
#       5 from hqq.engine.hf import HQQModelForCausalLM, AutoTokenizer
#       6 tokenizer = AutoTokenizer.from_pretrained(model_id)
# ----> 7 model     = HQQModelForCausalLM.from_quantized(model_id, compute_dtype=torch.float16, device="auto")
#
# /usr/local/lib/python3.11/dist-packages/hqq/engine/base.py in from_quantized(cls, save_dir_or_hub, compute_dtype, device, cache_dir, adapter)
#      85         cls._check_arch_support(arch_key)
#      86
# ---> 87         model = cls._get_hqq_class(arch_key).from_quantized(
#      88             save_dir,
#      89             compute_dtype=compute_dtype,
#
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py in from_quantized(cls, save_dir_or_hub, compute_dtype, device, cache_dir, adapter, **kwargs)
#     465         except Exception:
#     466             print("Failed to load the weights")
# --> 467             raise FileNotFoundError
#     468
#     469         # load_state_dict() doesn't work with modules initialized with init_empty_weights(), so we need to do this manually
#
# FileNotFoundError:

# %% [markdown]
# (save_dir_or_hub: Any, compute_dtype: dtype = float16, device: str = "cuda", cache_dir: str | None = "", adapter: str = None) -> Any

# %%
device_map='auto'

# %%
import torch
from transformers import AutoTokenizer
from hqq.models.hf.base import AutoHQQHFModel
from hqq.core.quantize import *
from hqq.utils.patching import *
from hqq.utils.generation_hf import HFGenerator

#Settings
###################################################
backend       = "bitblas" #bitblas or gemlite for 2-bit runtime
compute_dtype = torch.bfloat16 if backend=="torchao_int4" else torch.float16
device        = 'cuda:0'
cache_dir     = '.'

#Load the model
###################################################
model_id = 'mobiuslabsgmbh/Llama-2-70b-hf-2bit_g16_s128-HQQ'
model     = AutoHQQHFModel.from_quantized(model_id, cache_dir=cache_dir, compute_dtype=compute_dtype, device=device, adapter='adapter_v0.1.lora').eval();
tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir=cache_dir)

#Use optimized inference kernels
###################################################
prepare_for_inference(model, backend=backend) #It takes a while...

#Generate
###################################################
#For longer context, make sure to allocate enough cache via the cache_size= parameter
#gen = HFGenerator(model, tokenizer, max_new_tokens=1000, do_sample=True, compile=None) #Slower generation but no warm-up
gen = HFGenerator(model, tokenizer, max_new_tokens=10, do_sample=True, compile="partial").warmup() #Faster generation, but warm-up takes a while

gen.generate("Write an essay about large language models", print_tokens=True)
#gen.generate("Tell me a funny joke!", print_tokens=True)
#gen.generate("How to make a yummy chocolate cake?", print_tokens=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py:237: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
# Failed to load the weights
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py in from_quantized(cls, save_dir_or_hub, compute_dtype, device, cache_dir, adapter, **kwargs)
#     463         try:
# --> 464             weights = cls.load_weights(save_dir)
#     465         except Exception:
#
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py in load_weights(cls, save_dir, map_location)
#     236     def load_weights(cls, save_dir: str, map_location=None):
# --> 237         return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
#     238
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1096                         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1097                 return _load(
#    1098                     opened_zipfile,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1524     torch._utils._thread_local_state.map_location = map_location
# -> 1525     result = unpickler.load()
#    1526     del torch._utils._thread_local_state.map_location
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in persistent_load(saved_id)
#    1491             nbytes = numel * torch._utils._element_size(dtype)
# -> 1492             typed_storage = load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#    1493
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load_tensor(dtype, numel, key, location)
#    1465         typed_storage = torch.storage.TypedStorage(
# -> 1466             wrap_storage=restore_location(storage, location),
#    1467             dtype=dtype,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in default_restore_location(storage, location)
#     413     for _, _, fn in _package_registry:
# --> 414         result = fn(storage, location)
#     415         if result is not None:
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _deserialize(backend_name, obj, location)
#     391         device = _validate_device(location, backend_name)
# --> 392         return obj.to(device=device)
#     393
#
# /usr/local/lib/python3.11/dist-packages/torch/storage.py in to(self, device, non_blocking)
#     186     def to(self, *, device: torch.device, non_blocking: bool = False) -> T:  # type: ignore[type-var, misc] # noqa: E704
# --> 187         return _to(self, device, non_blocking)
#     188
#
# /usr/local/lib/python3.11/dist-packages/torch/_utils.py in _to(self, device, non_blocking)
#      88             ), f"sparse storage is not supported for {device.type.upper()} tensors"
# ---> 89             untyped_storage = torch.UntypedStorage(self.size(), device=device)
#      90             untyped_storage.copy_(self, non_blocking)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 16.12 MiB is free. Process 148432 has 14.72 GiB memory in use. Of the allocated memory 14.62 GiB is allocated by PyTorch, and 1.30 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-c9c7f7f4fcfb> in <cell line: 0>()
#      16 ###################################################
#      17 model_id = 'mobiuslabsgmbh/Llama-2-70b-hf-2bit_g16_s128-HQQ'
# ---> 18 model     = AutoHQQHFModel.from_quantized(model_id, cache_dir=cache_dir, compute_dtype=compute_dtype, device=device, adapter='adapter_v0.1.lora').eval();
#      19 tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir=cache_dir)
#      20
#
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py in from_quantized(cls, save_dir_or_hub, compute_dtype, device, cache_dir, adapter, **kwargs)
#     465         except Exception:
#     466             print("Failed to load the weights")
# --> 467             raise FileNotFoundError
#     468
#     469         # load_state_dict() doesn't work with modules initialized with init_empty_weights(), so we need to do this manually
#
# FileNotFoundError:

# %%
import torch
from transformers import AutoTokenizer
from hqq.models.hf.base import AutoHQQHFModel
from hqq.core.quantize import *
from hqq.utils.patching import *
from hqq.utils.generation_hf import HFGenerator

# Settings
###################################################
backend       = "bitblas" #bitblas or gemlite for 2-bit runtime
compute_dtype = torch.bfloat16 if backend=="torchao_int4" else torch.float16
cache_dir     = '.'

# Device Selection: Auto-detect GPU or use CPU
if torch.cuda.is_available():
    device = 'cuda:0'
    print("GPU is available. Using CUDA.")
else:
    device = 'cpu'
    print("GPU is not available. Using CPU.")

# Load the model
###################################################
model_id = 'mobiuslabsgmbh/Llama-2-70b-hf-2bit_g16_s128-HQQ'

try:
    model     = AutoHQQHFModel.from_quantized(model_id, cache_dir=cache_dir, compute_dtype=compute_dtype, device=device, adapter='adapter_v0.1.lora').eval()
    tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir=cache_dir)
except Exception as e:
    print(f"Error loading model on {device}: {e}")
    if device == 'cuda:0':
        print("Trying to load model on CPU instead due to potential GPU memory issues.")
        device = 'cpu' # Fallback to CPU if GPU loading fails
        try:
            model     = AutoHQQHFModel.from_quantized(model_id, cache_dir=cache_dir, compute_dtype=compute_dtype, device=device, adapter='adapter_v0.1.lora').eval()
            tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir=cache_dir)
        except Exception as e_cpu:
            print(f"Error loading model even on CPU: {e_cpu}")
            print("It seems there might be issues loading the model even on CPU. Please check your environment, disk space, and internet connection. ")
            exit() # Exit if loading fails even on CPU
    else: # If already tried CPU and failed
        print("Model loading failed on CPU. Please check your environment and model files.")
        exit()


# Use optimized inference kernels
###################################################
try:
    prepare_for_inference(model, backend=backend) #It takes a while...
    print(f"Model prepared for inference with backend '{backend}' on {device}.")
except Exception as e:
    print(f"Error preparing model for inference: {e}")
    print("Inference might still work, but performance could be suboptimal.")


# Generate
###################################################
#For longer context, make sure to allocate enough cache via the cache_size= parameter
#gen = HFGenerator(model, tokenizer, max_new_tokens=1000, do_sample=True, compile=None) #Slower generation but no warm-up
gen = HFGenerator(model, tokenizer, max_new_tokens=10, do_sample=True, compile="partial").warmup() #Faster generation, but warm-up takes a while

print("\nGenerating text:")
try:
    gen.generate("Write an essay about large language models", print_tokens=True)
    #gen.generate("Tell me a funny joke!", print_tokens=True)
    #gen.generate("How to make a yummy chocolate cake?", print_tokens=True)
except Exception as e:
    print(f"Error during text generation: {e}")
    print("Please check the error message and your environment.")
# Out:
# GPU is available. Using CUDA.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py:237: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
# Failed to load the weights
# Error loading model on cuda:0:
# Trying to load model on CPU instead due to potential GPU memory issues.
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# Failed to load the weights
# Error loading model even on CPU:
# It seems there might be issues loading the model even on CPU. Please check your environment, disk space, and internet connection.
# Error preparing model for inference: name 'model' is not defined
# Inference might still work, but performance could be suboptimal.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-17d613e79954> in <cell line: 0>()
#      58 #For longer context, make sure to allocate enough cache via the cache_size= parameter
#      59 #gen = HFGenerator(model, tokenizer, max_new_tokens=1000, do_sample=True, compile=None) #Slower generation but no warm-up
# ---> 60 gen = HFGenerator(model, tokenizer, max_new_tokens=10, do_sample=True, compile="partial").warmup() #Faster generation, but warm-up takes a while
#      61
#      62 print("\nGenerating text:")
#
# NameError: name 'model' is not defined

# %%
import torch
from transformers import AutoTokenizer
from hqq.models.hf.base import AutoHQQHFModel
from hqq.core.quantize import *
from hqq.utils.patching import *
from hqq.utils.generation_hf import HFGenerator

# Settings
###################################################
backend       = "bitblas" #bitblas or gemlite for 2-bit runtime
compute_dtype = torch.bfloat16 if backend=="torchao_int4" else torch.float16
cache_dir     = '.'

# Device Selection: Auto-detect GPU or use CPU
if torch.cuda.is_available():
    device = 'cuda:0'
    print("GPU is available. Using CUDA.")
else:
    device = 'cpu'
    print("GPU is not available. Using CPU.")

# Load the model
###################################################
model_id = 'mobiuslabsgmbh/Llama-2-70b-hf-2bit_g16_s128-HQQ'
model = None # Initialize model to None

try:
    model     = AutoHQQHFModel.from_quantized(model_id, cache_dir=cache_dir, compute_dtype=compute_dtype, device=device, adapter='adapter_v0.1.lora').eval()
    tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir=cache_dir)
except Exception as e:
    print(f"Error loading model on {device}: {e}")
    if device == 'cuda:0':
        print("Trying to load model on CPU instead due to potential GPU memory issues.")
        device = 'cpu' # Fallback to CPU if GPU loading fails
        try:
            model     = AutoHQQHFModel.from_quantized(model_id, cache_dir=cache_dir, compute_dtype=compute_dtype, device=device, adapter='adapter_v0.1.lora').eval()
            tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir=cache_dir)
        except Exception as e_cpu:
            print(f"Error loading model even on CPU: {e_cpu}")
            print("It seems there might be issues loading the model even on CPU. Please check your environment, disk space, and internet connection. ")
            exit() # Exit if loading fails even on CPU
    else: # If already tried CPU and failed
        print("Model loading failed on CPU. Please check your environment and model files.")
        exit()

# Check if model loaded successfully before proceeding
if model is None:
    print("Model loading failed. Exiting.")
    exit()

# Use optimized inference kernels
###################################################
try:
    prepare_for_inference(model, backend=backend) #It takes a while...
    print(f"Model prepared for inference with backend '{backend}' on {device}.")
except Exception as e:
    print(f"Error preparing model for inference: {e}")
    print("Inference might still work, but performance could be suboptimal.")


# Generate
###################################################
#For longer context, make sure to allocate enough cache via the cache_size= parameter
#gen = HFGenerator(model, tokenizer, max_new_tokens=1000, do_sample=True, compile=None) #Slower generation but no warm-up
gen = HFGenerator(model, tokenizer, max_new_tokens=10, do_sample=True, compile="partial").warmup() #Faster generation, but warm-up takes a while

print("\nGenerating text:")
try:
    gen.generate("Write an essay about large language models", print_tokens=True)
    #gen.generate("Tell me a funny joke!", print_tokens=True)
    #gen.generate("How to make a yummy chocolate cake?", print_tokens=True)
except Exception as e:
    print(f"Error during text generation: {e}")
    print("Please check the error message and your environment.")
# Out:
# GPU is available. Using CUDA.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py:237: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
# Failed to load the weights
# Error loading model on cuda:0:
# Trying to load model on CPU instead due to potential GPU memory issues.
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# Failed to load the weights
# Error loading model even on CPU:
# It seems there might be issues loading the model even on CPU. Please check your environment, disk space, and internet connection.
# Model loading failed. Exiting.
# Error preparing model for inference: 'NoneType' object has no attribute 'named_modules'
# Inference might still work, but performance could be suboptimal.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-74cb922ddb7f> in <cell line: 0>()
#      63 #For longer context, make sure to allocate enough cache via the cache_size= parameter
#      64 #gen = HFGenerator(model, tokenizer, max_new_tokens=1000, do_sample=True, compile=None) #Slower generation but no warm-up
# ---> 65 gen = HFGenerator(model, tokenizer, max_new_tokens=10, do_sample=True, compile="partial").warmup() #Faster generation, but warm-up takes a while
#      66
#      67 print("\nGenerating text:")
#
# NameError: name 'tokenizer' is not defined

# %%
import torch
from transformers import AutoTokenizer
from hqq.models.hf.base import AutoHQQHFModel
from hqq.core.quantize import *
from hqq.utils.patching import *
from hqq.utils.generation_hf import HFGenerator

# Settings
###################################################
backend       = "bitblas" #bitblas or gemlite for 2-bit runtime
compute_dtype = torch.bfloat16 if backend=="torchao_int4" else torch.float16
cache_dir     = '.'

# Device Selection: Auto-detect GPU or use CPU
if torch.cuda.is_available():
    device = 'cuda:0'
    print("GPU is available. Using CUDA.")
else:
    device = 'cpu'
    print("GPU is not available. Using CPU.")

# Load the model and tokenizer
###################################################
model_id = 'mobiuslabsgmbh/Llama-2-70b-hf-2bit_g16_s128-HQQ'
model = None  # Initialize model to None
tokenizer = None # Initialize tokenizer to None

try:
    model     = AutoHQQHFModel.from_quantized(model_id, cache_dir=cache_dir, compute_dtype=compute_dtype, device=device, adapter='adapter_v0.1.lora').eval()
    tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir=cache_dir)
except Exception as e:
    print(f"Error loading model and tokenizer on {device}: {e}")
    if device == 'cuda:0':
        print("Trying to load model and tokenizer on CPU instead due to potential GPU memory issues.")
        device = 'cpu' # Fallback to CPU if GPU loading fails
        try:
            model     = AutoHQQHFModel.from_quantized(model_id, cache_dir=cache_dir, compute_dtype=compute_dtype, device=device, adapter='adapter_v0.1.lora').eval()
            tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir=cache_dir)
        except Exception as e_cpu:
            print(f"Error loading model and tokenizer even on CPU: {e_cpu}")
            print("It seems there might be issues loading the model and tokenizer even on CPU. Please check your environment, disk space, and internet connection. ")
            exit() # Exit if loading fails even on CPU
    else: # If already tried CPU and failed
        print("Model and tokenizer loading failed on CPU. Please check your environment and model files.")
        exit()

# Check if model and tokenizer loaded successfully before proceeding
if model is None or tokenizer is None:
    print("Model or Tokenizer loading failed. Exiting.")
    exit()

# Use optimized inference kernels
###################################################
try:
    prepare_for_inference(model, backend=backend) #It takes a while...
    print(f"Model prepared for inference with backend '{backend}' on {device}.")
except Exception as e:
    print(f"Error preparing model for inference: {e}")
    print("Inference might still work, but performance could be suboptimal.")


# Generate
###################################################
#For longer context, make sure to allocate enough cache via the cache_size= parameter
#gen = HFGenerator(model, tokenizer, max_new_tokens=1000, do_sample=True, compile=None) #Slower generation but no warm-up
gen = HFGenerator(model, tokenizer, max_new_tokens=10, do_sample=True, compile="partial").warmup() #Faster generation, but warm-up takes a while

print("\nGenerating text:")
try:
    gen.generate("Write an essay about large language models", print_tokens=True)
    #gen.generate("Tell me a funny joke!", print_tokens=True)
    #gen.generate("How to make a yummy chocolate cake?", print_tokens=True)
except Exception as e:
    print(f"Error during text generation: {e}")
    print("Please check the error message and your environment.")
# Out:
# GPU is available. Using CUDA.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py:237: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
# Failed to load the weights
# Error loading model and tokenizer on cuda:0:
# Trying to load model and tokenizer on CPU instead due to potential GPU memory issues.
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# Failed to load the weights
# Error loading model and tokenizer even on CPU:
# It seems there might be issues loading the model and tokenizer even on CPU. Please check your environment, disk space, and internet connection.
# Model or Tokenizer loading failed. Exiting.
# Error preparing model for inference: 'NoneType' object has no attribute 'named_modules'
# Inference might still work, but performance could be suboptimal.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-9f5b5cc396d7> in <cell line: 0>()
#      64 #For longer context, make sure to allocate enough cache via the cache_size= parameter
#      65 #gen = HFGenerator(model, tokenizer, max_new_tokens=1000, do_sample=True, compile=None) #Slower generation but no warm-up
# ---> 66 gen = HFGenerator(model, tokenizer, max_new_tokens=10, do_sample=True, compile="partial").warmup() #Faster generation, but warm-up takes a while
#      67
#      68 print("\nGenerating text:")
#
# /usr/local/lib/python3.11/dist-packages/hqq/utils/generation_hf.py in __init__(self, model, tokenizer, max_new_tokens, cache_size, do_sample, temperature, top_k, compile)
#      37         self.model = model
#      38         self.tokenizer = tokenizer
# ---> 39         self.device = model.device
#      40         self.do_sample = do_sample
#      41         self.temperature = temperature if self.do_sample else None
#
# AttributeError: 'NoneType' object has no attribute 'device'

# %%
import torch
from transformers import AutoTokenizer
from hqq.models.hf.base import AutoHQQHFModel
from hqq.core.quantize import *
from hqq.utils.patching import *
from hqq.utils.generation_hf import HFGenerator

# Settings
###################################################
backend       = "bitblas" #bitblas or gemlite for 2-bit runtime
compute_dtype = torch.bfloat16 if backend=="torchao_int4" else torch.float16
cache_dir     = '.'

# Device Selection: Auto-detect GPU or use CPU
if torch.cuda.is_available():
    device = 'cuda:0'
    print("GPU is available. Using CUDA.")
else:
    device = 'cpu'
    print("GPU is not available. Using CPU.")

# Load the model and tokenizer
###################################################
model_id = 'mobiuslabsgmbh/Llama-2-70b-hf-2bit_g16_s128-HQQ'
model = None  # Initialize model to None
tokenizer = None # Initialize tokenizer to None

try:
    print(f"Attempting to load model on {device}...") # Debugging print
    model     = AutoHQQHFModel.from_quantized(model_id, cache_dir=cache_dir, compute_dtype=compute_dtype, device=device, adapter='adapter_v0.1.lora').eval()
    tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir=cache_dir)
    print(f"Model and tokenizer loaded successfully on {device}.") # Debugging print

except Exception as e:
    print(f"Error loading model and tokenizer on {device}: {e}")
    if device == 'cuda:0':
        print("Trying to load model and tokenizer on CPU instead due to potential GPU memory issues.")
        device = 'cpu' # Fallback to CPU if GPU loading fails
        try:
            print(f"Attempting to load model on CPU...") # Debugging print
            model     = AutoHQQHFModel.from_quantized(model_id, cache_dir=cache_dir, compute_dtype=compute_dtype, device=device, adapter='adapter_v0.1.lora').eval()
            tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir=cache_dir)
            print(f"Model and tokenizer loaded successfully on CPU.") # Debugging print
        except Exception as e_cpu:
            print(f"Error loading model and tokenizer even on CPU: {e_cpu}")
            print("It seems there might be issues loading the model and tokenizer even on CPU. Please check your environment, disk space, and internet connection. ")
            exit() # Exit if loading fails even on CPU
    else: # If already tried CPU and failed
        print("Model and tokenizer loading failed on CPU. Please check your environment and model files.")
        exit()

# Check if model and tokenizer loaded successfully before proceeding
if model is None or tokenizer is None:
    print("Model or Tokenizer loading failed. Exiting.")
    exit()

# Use optimized inference kernels
###################################################
try:
    prepare_for_inference(model, backend=backend) #It takes a while...
    print(f"Model prepared for inference with backend '{backend}' on {device}.")
except Exception as e:
    print(f"Error preparing model for inference: {e}")
    print("Inference might still work, but performance could be suboptimal.")


# Generate
###################################################
#For longer context, make sure to allocate enough cache via the cache_size= parameter
#gen = HFGenerator(model, tokenizer, max_new_tokens=1000, do_sample=True, compile=None) #Slower generation but no warm-up
gen = HFGenerator(model, tokenizer, max_new_tokens=10, do_sample=True, compile="partial").warmup() #Faster generation, but warm-up takes a while

print("\nGenerating text:")
try:
    gen.generate("Write an essay about large language models", print_tokens=True)
    #gen.generate("Tell me a funny joke!", print_tokens=True)
    #gen.generate("How to make a yummy chocolate cake?", print_tokens=True)
except Exception as e:
    print(f"Error during text generation: {e}")
    print("Please check the error message and your environment.")
# Out:
# GPU is available. Using CUDA.
# Attempting to load model on cuda:0...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py:237: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
# Failed to load the weights
# Error loading model and tokenizer on cuda:0:
# Trying to load model and tokenizer on CPU instead due to potential GPU memory issues.
# Attempting to load model on CPU...
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# Failed to load the weights
# Error loading model and tokenizer even on CPU:
# It seems there might be issues loading the model and tokenizer even on CPU. Please check your environment, disk space, and internet connection.
# Model or Tokenizer loading failed. Exiting.
# Error preparing model for inference: 'NoneType' object has no attribute 'named_modules'
# Inference might still work, but performance could be suboptimal.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-3d2c2322589e> in <cell line: 0>()
#      69 #For longer context, make sure to allocate enough cache via the cache_size= parameter
#      70 #gen = HFGenerator(model, tokenizer, max_new_tokens=1000, do_sample=True, compile=None) #Slower generation but no warm-up
# ---> 71 gen = HFGenerator(model, tokenizer, max_new_tokens=10, do_sample=True, compile="partial").warmup() #Faster generation, but warm-up takes a while
#      72
#      73 print("\nGenerating text:")
#
# /usr/local/lib/python3.11/dist-packages/hqq/utils/generation_hf.py in __init__(self, model, tokenizer, max_new_tokens, cache_size, do_sample, temperature, top_k, compile)
#      37         self.model = model
#      38         self.tokenizer = tokenizer
# ---> 39         self.device = model.device
#      40         self.do_sample = do_sample
#      41         self.temperature = temperature if self.do_sample else None
#
# AttributeError: 'NoneType' object has no attribute 'device'

# %%
import shutil
import os

cache_dir = os.path.expanduser("~/.cache/huggingface/hub") # Standard HF cache path

if os.path.exists(cache_dir):
    print(f"Deleting cache directory: {cache_dir}")
    shutil.rmtree(cache_dir)
    print(f"Cache directory deleted.")
else:
    print(f"Cache directory not found at: {cache_dir}")

# You can also try clearing the 'local' cache if the above doesn't work fully
local_cache_dir = "./.huggingface/hub" # Local cache in your current directory (if used)
if os.path.exists(local_cache_dir):
    print(f"Deleting local cache directory: {local_cache_dir}")
    shutil.rmtree(local_cache_dir)
    print(f"Local cache directory deleted.")
else:
    print(f"Local cache directory not found at: {local_cache_dir}")


print("Cache clearing process completed.")
# Out:
# Deleting cache directory: /root/.cache/huggingface/hub
# Cache directory deleted.
# Local cache directory not found at: ./.huggingface/hub
# Cache clearing process completed.

# %%
# !df -h /content
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         113G   70G   44G  62% /

# %%
import torch
from transformers import AutoTokenizer
from hqq.models.hf.base import AutoHQQHFModel
from hqq.core.quantize import *
from hqq.utils.patching import *
from hqq.utils.generation_hf import HFGenerator

# Settings
###################################################
backend       = "bitblas" #bitblas or gemlite for 2-bit runtime
compute_dtype = torch.bfloat16 if backend=="torchao_int4" else torch.float16
cache_dir     = '.'

# Device Selection: Auto-detect GPU or use CPU
if torch.cuda.is_available():
    device = 'cuda:0'
    print("GPU is available. Using CUDA.")
else:
    device = 'cpu'
    print("GPU is not available. Using CPU.")

# Load the model and tokenizer
###################################################
model_id = 'mobiuslabsgmbh/Llama-2-70b-hf-2bit_g16_s128-HQQ'
model = None  # Initialize model to None
tokenizer = None # Initialize tokenizer to None

try:
    print(f"Attempting to load model on {device}...") # Debugging print
    model     = AutoHQQHFModel.from_quantized(model_id, cache_dir=cache_dir, compute_dtype=compute_dtype, device=device, adapter='adapter_v0.1.lora').eval()
    tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir=cache_dir)
    print(f"Model and tokenizer loaded successfully on {device}.") # Debugging print

except Exception as e:
    print(f"Error loading model and tokenizer on {device}: {e}")
    if device == 'cuda:0':
        print("Trying to load model and tokenizer on CPU instead due to potential GPU memory issues.")
        device = 'cpu' # Fallback to CPU if GPU loading fails
        try:
            print(f"Attempting to load model on CPU...") # Debugging print
            model     = AutoHQQHFModel.from_quantized(model_id, cache_dir=cache_dir, compute_dtype=compute_dtype, device=device, adapter='adapter_v0.1.lora').eval()
            tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir=cache_dir)
            print(f"Model and tokenizer loaded successfully on CPU.") # Debugging print
        except Exception as e_cpu:
            print(f"Error loading model and tokenizer even on CPU: {e_cpu}")
            print("It seems there might be issues loading the model and tokenizer even on CPU. Please check your environment, disk space, and internet connection. ")
            exit() # Exit if loading fails even on CPU
    else: # If already tried CPU and failed
        print("Model and tokenizer loading failed on CPU. Please check your environment and model files.")
        exit()

# Check if model and tokenizer loaded successfully before proceeding
if model is None or tokenizer is None:
    print("Model or Tokenizer loading failed. Exiting.")
    exit()

# Use optimized inference kernels
###################################################
try:
    prepare_for_inference(model, backend=backend) #It takes a while...
    print(f"Model prepared for inference with backend '{backend}' on {device}.")
except Exception as e:
    print(f"Error preparing model for inference: {e}")
    print("Inference might still work, but performance could be suboptimal.")


# Generate
###################################################
#For longer context, make sure to allocate enough cache via the cache_size= parameter
#gen = HFGenerator(model, tokenizer, max_new_tokens=1000, do_sample=True, compile=None) #Slower generation but no warm-up
gen = HFGenerator(model, tokenizer, max_new_tokens=10, do_sample=True, compile="partial").warmup() #Faster generation, but warm-up takes a while

print("\nGenerating text:")
try:
    gen.generate("Write an essay about large language models", print_tokens=True)
    #gen.generate("Tell me a funny joke!", print_tokens=True)
    #gen.generate("How to make a yummy chocolate cake?", print_tokens=True)
except Exception as e:
    print(f"Error during text generation: {e}")
    print("Please check the error message and your environment.")
# Out:
# GPU is available. Using CUDA.
# Attempting to load model on cuda:0...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/hqq/models/base.py:237: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cls.get_weight_file(save_dir), map_location=map_location)
# Failed to load the weights
# Error loading model and tokenizer on cuda:0:
# Trying to load model and tokenizer on CPU instead due to potential GPU memory issues.
# Attempting to load model on CPU...
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# Failed to load the weights
# Error loading model and tokenizer even on CPU:
# It seems there might be issues loading the model and tokenizer even on CPU. Please check your environment, disk space, and internet connection.
# Model or Tokenizer loading failed. Exiting.
# Error preparing model for inference: 'NoneType' object has no attribute 'named_modules'
# Inference might still work, but performance could be suboptimal.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-3d2c2322589e> in <cell line: 0>()
#      69 #For longer context, make sure to allocate enough cache via the cache_size= parameter
#      70 #gen = HFGenerator(model, tokenizer, max_new_tokens=1000, do_sample=True, compile=None) #Slower generation but no warm-up
# ---> 71 gen = HFGenerator(model, tokenizer, max_new_tokens=10, do_sample=True, compile="partial").warmup() #Faster generation, but warm-up takes a while
#      72
#      73 print("\nGenerating text:")
#
# /usr/local/lib/python3.11/dist-packages/hqq/utils/generation_hf.py in __init__(self, model, tokenizer, max_new_tokens, cache_size, do_sample, temperature, top_k, compile)
#      37         self.model = model
#      38         self.tokenizer = tokenizer
# ---> 39         self.device = model.device
#      40         self.do_sample = do_sample
#      41         self.temperature = temperature if self.do_sample else None
#
# AttributeError: 'NoneType' object has no attribute 'device'
